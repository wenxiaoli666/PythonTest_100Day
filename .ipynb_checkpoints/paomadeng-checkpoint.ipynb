# %%
import os
import time

def main():
    content = "here is pao ma deng Running......"
    while True:
        os.system('cls')
        print(content)
        time.sleep(0.2)
        content = content[1:]+content[0]

if __name__ == '__main__':
    main()
# Out:
# here is pao ma deng Running......
# ere is pao ma deng Running......h
# re is pao ma deng Running......he
# e is pao ma deng Running......her
#  is pao ma deng Running......here
# is pao ma deng Running......here
# s pao ma deng Running......here i
#  pao ma deng Running......here is
# pao ma deng Running......here is
# ao ma deng Running......here is p
# o ma deng Running......here is pa
#  ma deng Running......here is pao
# ma deng Running......here is pao
# a deng Running......here is pao m
#  deng Running......here is pao ma
# deng Running......here is pao ma
# eng Running......here is pao ma d
# ng Running......here is pao ma de
# g Running......here is pao ma den
#  Running......here is pao ma deng
# Running......here is pao ma deng
# unning......here is pao ma deng R
# nning......here is pao ma deng Ru
# ning......here is pao ma deng Run
# ing......here is pao ma deng Runn
# ng......here is pao ma deng Runni
# g......here is pao ma deng Runnin
# ...
